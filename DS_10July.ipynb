# %%
import pandas as pd

# %%
food1= {'number1':[1,2,3,4,5],'name':['apple','banana','chips','popcorn','pizza'],'price':[2,4,7,8,6]}

# %%
pd.DataFrame(food1)
# Out:
#    number1     name  price
# 0        1    apple      2
# 1        2   banana      4
# 2        3    chips      7
# 3        4  popcorn      8
# 4        5    pizza      6

# %%
print(fruits)
# Out:
#    Apple  Banana
# 0     30      21

# %%
import scipy as sp
from scipy import integrate

# %%
from scipy import fftpack

# %%
help(fftpack)
# Out:
# Help on package scipy.fftpack in scipy:
#
# NAME
#     scipy.fftpack
#
# DESCRIPTION
# ...
#     Legacy discrete Fourier transforms (:mod:`scipy.fftpack`)
# ...
#
#     .. warning::
#
#        This submodule is now considered legacy, new code should use
#        :mod:`scipy.fft`.
#
#     Fast Fourier Transforms (FFTs)
# ...
#
#     .. autosummary::
#        :toctree: generated/
#
#        fft - Fast (discrete) Fourier Transform (FFT)
#        ifft - Inverse FFT
#        fft2 - 2-D FFT
#        ifft2 - 2-D inverse FFT
#        fftn - N-D FFT
#        ifftn - N-D inverse FFT
#        rfft - FFT of strictly real-valued sequence
#        irfft - Inverse of rfft
#        dct - Discrete cosine transform
#        idct - Inverse discrete cosine transform
#        dctn - N-D Discrete cosine transform
#        idctn - N-D Inverse discrete cosine transform
#        dst - Discrete sine transform
#        idst - Inverse discrete sine transform
#        dstn - N-D Discrete sine transform
# ...

# %%
sp.info(fftpack)
# Out:
# ...
# Legacy discrete Fourier transforms (:mod:`scipy.fftpack`)
# ...
#
# .. warning::
#
#    This submodule is now considered legacy, new code should use
#    :mod:`scipy.fft`.
#
# Fast Fourier Transforms (FFTs)
# ...
#
# .. autosummary::
#    :toctree: generated/
#
#    fft - Fast (discrete) Fourier Transform (FFT)
#    ifft - Inverse FFT
#    fft2 - 2-D FFT
#    ifft2 - 2-D inverse FFT
#    fftn - N-D FFT
#    ifftn - N-D inverse FFT
#    rfft - FFT of strictly real-valued sequence
#    irfft - Inverse of rfft
#    dct - Discrete cosine transform
#    idct - Inverse discrete cosine transform
#    dctn - N-D Discrete cosine transform
#    idctn - N-D Inverse discrete cosine transform
#    dst - Discrete sine transform
#    idst - Inverse discrete sine transform
#    dstn - N-D Discrete sine transform
#    idstn - N-D Inverse discrete sine transform
#
# Differential and pseudo-differential operators
# ...
#
# .. autosummary::
#    :toctree: generated/
#
# ...

# %%
import scipy as sp
from scipy import special

# %%
special.kelvin(12)
# Out:
# ((-128.51162615774032+546.9485524630747j),
#  (-6.307713705210742e-05-3.899959497124564e-05j),
#  (-472.56881635370206+272.67002155389184j),
#  (1.9593852092301425e-05+7.381496296013578e-05j))

# %%
special.xlogy(2,5)
# Out:
# 3.2188758248682006

# %%
special.exp10(4)
# Out:
# 10000.0

# %%
special.sindg(90)
# Out:
# 1.0
