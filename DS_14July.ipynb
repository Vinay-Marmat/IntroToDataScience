# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns

# %%
database = sns.load_dataset('tips')

# %%
database.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='tip',y='total_bill',data=database)

# %%
database = sns.load_dataset('flights')

# %%
sns.catplot(x='month',y='passengers',data= database, kind='violin')

# %%
sns.boxplot(x='month',y='passengers',data=database)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
database=sns.load_dataset('tips')

# %%
graph = sns.FacetGrid(database,col='time',hue='size')
graph.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8742e6a3d3d2> in <module>
#       1 graph = sns.FacetGrid(database,col='time',hue='size')
# ----> 2 graph.legend()
#
# TypeError: 'NoneType' object is not callable

# %%
graph.map(plt.scatter,'total_bill','tip')
